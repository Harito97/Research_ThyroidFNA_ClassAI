# %% [markdown]
# # CNN
#
# 1. VGG
#
#     VGG16 (ít tham số nhất)
#     + Số lượng lớp: 16
#     + Số tham số: Khoảng 138 triệu
#
#     VGG19 (nhiều tham số nhất)
#     + Số lượng lớp: 19
#     + Số tham số: Khoảng 143 triệu
#
# 2. ResNet
#
#     ResNet18 (ít tham số nhất)
#     + Số lượng lớp: 18
#     + Số tham số: Khoảng 11 triệu
#
#     ResNet152 (nhiều tham số nhất)
#     + Số lượng lớp: 152
#     + Số tham số: Khoảng 60 triệu
#
# 3. DenseNet
#
#     DenseNet121 (ít tham số nhất)
#     + Số lượng lớp: 121
#     + Số tham số: Khoảng 8 triệu
#
#     DenseNet201 (nhiều tham số nhất)
#     + Số lượng lớp: 201
#     + Số tham số: Khoảng 20 triệu
#
# 4. EfficientNet
#
#     EfficientNetB0 (ít tham số nhất)
#     + Số lượng lớp: 23
#     + Số tham số: Khoảng 5 triệu
#
#     EfficientNetB7 (nhiều tham số nhất)
#     + Số lượng lớp: 52
#     + Số tham số: Khoảng 66 triệu
#
# 5. MobileNet
#
#     MobileNetV1 (ít tham số nhất)
#     + Số lượng lớp: 28
#     + Số tham số: Khoảng 4 triệu
#
#     MobileNetV3-Large (nhiều tham số nhất)
#     + Số lượng lớp: 39
#     + Số tham số: Khoảng 5.4 triệu
#
# # Vision Transformers (ViT)
#
# 1. ViT-B/16 (ít tham số nhất)
#
#     + Số lớp Transformer: 12
#     + Số tham số: Khoảng 86 triệu
#
# 2. ViT-L/16 (nhiều tham số nhất)
#
#     + Số lớp Transformer: 24
#     + Số tham số: Khoảng 307 triệu
