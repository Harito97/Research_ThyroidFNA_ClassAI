# %%
# !pwd
# %matplotlib inline  
# %pip install pickleshare
# Out:
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase2_280824/notebooks/explore

# %%
# %cd ../..
# Out:
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase2_280824

# %%
from src.data.explorer.before_pass_module1 import *

# %%
# !ls data
# Out:
# 1725013654_A_set  1725013654_D_set  1725071492_C_set	raw
# 1725013654_B_set  1725071492_A_set  1725071492_D_set
# 1725013654_C_set  1725071492_B_set  Origin_Bx-July.zip

# %%
folder_path = 'data/'
images = load_random_images(folder_path=folder_path, num_images=100)
print(len(images), len(images[0]), len(images[1]))
print(images[0][:5], images[1][:5], sep='\n')
# Out:
# Số lượng ảnh trong mỗi folder:
# data/1725013654_B_set/train/B6: 546 ảnh
# data/1725013654_B_set/train/B2: 337 ảnh
# data/1725013654_B_set/train/B5: 378 ảnh
# data/1725013654_B_set/valid/B6: 117 ảnh
# data/1725013654_B_set/valid/B2: 72 ảnh
# data/1725013654_B_set/valid/B5: 81 ảnh
# data/1725071492_D_set/train/B6: 7488 ảnh
# data/1725071492_D_set/train/B2: 4620 ảnh
# data/1725071492_D_set/train/B5: 5184 ảnh
# data/1725071492_D_set/valid/B6: 936 ảnh
# data/1725071492_D_set/valid/B2: 576 ảnh
# data/1725071492_D_set/valid/B5: 648 ảnh
# data/1725013654_D_set/train/B6: 6552 ảnh
# data/1725013654_D_set/train/B2: 4044 ảnh
# data/1725013654_D_set/train/B5: 4536 ảnh
# data/1725013654_D_set/valid/B6: 1404 ảnh
# data/1725013654_D_set/valid/B2: 864 ảnh
# data/1725013654_D_set/valid/B5: 972 ảnh
# data/1725013654_C_set/train/B6: 4368 ảnh
# data/1725013654_C_set/train/B2: 2696 ảnh
# data/1725013654_C_set/train/B5: 3024 ảnh
# data/1725013654_C_set/valid/B6: 936 ảnh
# ...

# %%
plot_images(images=images[0])

# %%
reduced_data = reduce_dimensionality(images=images[0])

# %%
plot_interactive_3d(data=reduced_data, labels=images[1])
