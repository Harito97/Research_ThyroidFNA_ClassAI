# %% [markdown]
# # Setup môi trường

# %%
import os
print(os.getcwd())
os.chdir("../../..")
print(os.getcwd())
# Out:
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase3_120924/notebooks/train_module2/with_aug_data_variance0_5
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase3_120924

# %% [markdown]
# # Setup data

# %%
import pandas as pd

# Đọc dữ liệu từ CSV
data_dir = './data/processed/'
# train_df = pd.read_csv(data_dir + 'train_features.csv').drop(columns=['image_path'])
valid_df = pd.read_csv(data_dir + 'valid_features.csv').drop(columns=['image_path'])
test_df = pd.read_csv(data_dir + 'test_features.csv').drop(columns=['image_path'])

data_dir = './data/augmented/'
train_df_aug = pd.read_csv(data_dir + 'train_augmented_features_variance_0_5.csv')

# Xem cấu trúc của DataFrame
# print('Train DataFrame:')
# print(train_df.head(3))
print('Valid DataFrame:')
print(valid_df.head(3))
print('Test DataFrame:')
print(test_df.head(3))
print('Train Augmented DataFrame:')
print(train_df_aug.head(3))
# Out:
# Valid DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2 -4.308372 -0.436520  3.545043 -2.595636 -1.076509  3.019734
# 1      2 -2.273990 -2.976918  4.630661 -5.481691  1.987185  3.077199
# 2      2 -4.070328 -3.232069  6.819434 -3.002290 -1.391492  3.774137
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -3.748788 -0.974676  4.619431  ...  4.596820 -4.209521 -0.469024  4.025341
# 1 -4.994466  1.433963  2.813911  ...  3.553807 -3.890979 -0.693126  4.631985
# 2 -2.197132 -2.203136  3.730880  ...  2.323358 -3.455380 -3.436366  6.039357
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -3.474844 -1.487661  5.017033 -1.916778 -0.383969  2.663312
# 1 -2.152809 -0.549343  3.090957 -1.015712 -1.852066  2.541131
# 2 -3.923026 -2.357094  5.158929 -4.472951 -3.406128  6.673154
#
# [3 rows x 40 columns]
# Test DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2 -3.796856  0.253959  2.877217 -5.331173  3.020115  1.696861
# 1      2 -1.773854 -2.388358  4.133105 -4.472247  2.485264  1.485237
# 2      2 -2.350752  0.081050  1.976886 -3.827375  2.962807  0.343403
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -5.202694  1.392334  2.969771  ...  3.350157 -3.535631  0.163143  2.530488
# 1 -4.855537 -0.433563  4.551636  ...  4.002171 -4.629158 -0.437382  4.171252
# 2 -5.119369  0.324123  3.400166  ...  0.545714 -3.568954 -0.028026  2.769698
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -4.519028  1.381369  2.529239 -1.612869  0.088159  2.034805
# 1 -4.309902 -0.884549  4.688826 -6.092622  0.102198  4.461133
# 2 -3.385958 -0.573338  3.277399 -0.740373  0.527510  0.592563
#
# [3 rows x 40 columns]
# Train Augmented DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2  1.518592 -2.122206  1.063359  1.083591 -3.078244  1.832143
# 1      2 -3.997844 -2.013066  5.606269 -2.221863  0.908517  0.995050
# 2      2 -4.144322 -3.335181  7.014940 -2.851661 -1.254374  4.090703
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -3.617894  1.835063  0.739837  ... -0.450482  0.230301  0.322319 -0.361697
# 1 -4.953275  1.075495  3.199515  ...  2.695855 -4.411282 -1.748895  5.605376
# 2 -3.888599 -2.345787  6.091836  ...  6.469357 -5.430499 -2.013651  6.954945
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -1.096648  1.402599  0.442939 -3.928780  2.343227  1.505659
# 1 -6.375985 -0.828269  6.179725 -4.965612  0.590781  3.893331
# 2 -3.220028 -1.721707  5.068684 -4.063029 -1.196603  5.176606
#
# [3 rows x 40 columns]

# %%
import torch
# Tính toán số lượng mẫu của mỗi lớp
class_counts = train_df_aug['label'].value_counts()
total_samples = len(train_df_aug)
class_weights = {cls: total_samples / (len(class_counts) * count) for cls, count in class_counts.items()}

# In ra thông tin trọng số
print("Class Weights (inverse frequency):")
print(class_weights)

# Chuyển đổi trọng số nhãn thành tensor
class_weights_tensor = torch.tensor(sorted(list(class_weights.values()), reverse=True), dtype=torch.float)
print(class_weights_tensor)
# Out:
# Class Weights (inverse frequency):
# {2: 0.7698412698412699, 1: 1.1119929453262787, 0: 1.2472799208704253}
# tensor([1.2473, 1.1120, 0.7698])

# %%
# %pip install kneed

# %%
# Flatten the data
X_train_flat = train_df_aug.iloc[:, 1:].values
X_valid_flat = valid_df.iloc[:, 1:].values
X_test_flat = test_df.iloc[:, 1:].values

import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Step 1: Standardize the data
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X_train_flat)
# skip standardization as the data is already standardized with same range
X_scaled = X_train_flat

# Step 2: Perform PCA
pca = PCA()
pca.fit(X_scaled)

# Step 3: Calculate explained variance and cumulative explained variance
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

# Step 4: Create visualizations
plt.figure(figsize=(20, 15))

# Plot 1: Scree plot
plt.subplot(2, 2, 1)
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, 'bo-')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')

# Plot 2: Cumulative explained variance plot
plt.subplot(2, 2, 2)
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, 'ro-')
plt.title('Cumulative Explained Variance Ratio')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')

# Add lines for 80%, 90%, and 95% explained variance
plt.axhline(y=0.8, color='g', linestyle='--', label='80% Explained Variance')
plt.axhline(y=0.9, color='b', linestyle='--', label='90% Explained Variance')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Explained Variance')
plt.legend()

# Plot 3: Explained variance for each component (bar plot)
plt.subplot(2, 2, 3)
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio)
plt.title('Explained Variance Ratio per Component')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')

# Plot 4: Cumulative explained variance (area plot)
plt.subplot(2, 2, 4)
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, 'ro-')
plt.fill_between(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio)
plt.title('Cumulative Explained Variance Ratio (Area Plot)')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')

plt.tight_layout()
plt.show()

# Step 5: Print additional information
print("Total number of components:", len(explained_variance_ratio))
print("\nExplained variance ratio for each component:")
for i, ratio in enumerate(explained_variance_ratio, 1):
    print(f"PC{i}: {ratio:.4f}")

print("\nNumber of components needed to explain:")
for threshold in [0.7, 0.8, 0.9, 0.95, 0.99]:
    n_components = np.where(cumulative_variance_ratio >= threshold)[0][0] + 1
    print(f"{threshold*100}% of variance: {n_components}")

# Step 6: Determine optimal number of components (elbow method)
from kneed import KneeLocator
n_components_range = range(1, len(explained_variance_ratio) + 1)
kneedle = KneeLocator(n_components_range, explained_variance_ratio, curve='convex', direction='decreasing')
print(f"\nOptimal number of components (elbow method): {kneedle.elbow}")

# Step 7: Transform the data using the optimal number of components
optimal_n_components = kneedle.elbow
pca_optimal = PCA(n_components=optimal_n_components)
X_pca = pca_optimal.fit_transform(X_scaled)

print(f"\nShape of the transformed data: {X_pca.shape}")
# Out:
# Total number of components: 39
#
# Explained variance ratio for each component:
# PC1: 0.6745
# PC2: 0.1891
# PC3: 0.0101
# PC4: 0.0089
# PC5: 0.0084
# PC6: 0.0076
# PC7: 0.0067
# PC8: 0.0065
# PC9: 0.0060
# PC10: 0.0059
# PC11: 0.0055
# PC12: 0.0052
# PC13: 0.0049
# PC14: 0.0047
# PC15: 0.0047
# PC16: 0.0044
# PC17: 0.0042
# PC18: 0.0040
# PC19: 0.0038
# PC20: 0.0036
# PC21: 0.0034
# PC22: 0.0033
# PC23: 0.0031
# PC24: 0.0029
# PC25: 0.0028
# PC26: 0.0026
# PC27: 0.0018
# PC28: 0.0010
# PC29: 0.0010
# PC30: 0.0010
# PC31: 0.0010
# PC32: 0.0010
# PC33: 0.0010
# PC34: 0.0009
# PC35: 0.0009
# PC36: 0.0009
# PC37: 0.0009
# PC38: 0.0009
# PC39: 0.0009
#
# Number of components needed to explain:
# 70.0% of variance: 2
# 80.0% of variance: 2
# 90.0% of variance: 7
# 95.0% of variance: 16
# 99.0% of variance: 29
#
# Optimal number of components (elbow method): 3
#
# Shape of the transformed data: (94575, 3)

# %% [markdown]
# # Với số thành phần component là 3

# %%
num_components_with_elbow_method = 3

# %%
from torch.utils.data import DataLoader, TensorDataset

# Apply PCA
n_components = num_components_with_elbow_method
pca = PCA(n_components=n_components)
pca.fit(X_train_flat)

# Transform the data
X_train_pca = pca.transform(X_train_flat)
X_valid_pca = pca.transform(X_valid_flat)
X_test_pca = pca.transform(X_test_flat)

# Convert to PyTorch tensors
X_train = torch.tensor(X_train_pca, dtype=torch.float32)
y_train = torch.tensor(train_df_aug['label'].values, dtype=torch.long)
X_valid = torch.tensor(X_valid_pca, dtype=torch.float32)
y_valid = torch.tensor(valid_df['label'].values, dtype=torch.long)
X_test = torch.tensor(X_test_pca, dtype=torch.float32)
y_test = torch.tensor(test_df['label'].values, dtype=torch.long)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)

# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=120, shuffle=True)   # tăng lên 1200 để cho nó nhanh 
valid_loader = DataLoader(valid_dataset, batch_size=120, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=120, shuffle=False)
# Out:
# torch.Size([94575, 3]) torch.Size([94575])
# torch.Size([270, 3]) torch.Size([270])
# torch.Size([273, 3]) torch.Size([273])

# %% [markdown]
# ## Huấn luyện mô hình

# %%
import torch
from src.models.module2.ann import ANN

model = ANN(input_dim=num_components_with_elbow_method, output_dim=3, num_hidden=9, num_layers=3, dropout=0.5)
num_params = sum(p.numel() for p in model.parameters())
print(num_params)
# Out:
# 246

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# set seed
torch.manual_seed(97)

model.to('cuda')
criterion.to('cuda')

num_epochs = 100
best_valid_loss = float('inf')
for epoch in range(num_epochs):
    model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    # Đánh giá mô hình trên tập validation
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)

    valid_loss /= len(valid_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss:.4f}, Validation Loss: {valid_loss:.4f}")

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'best_model_PCA3_ANN_withAug_var0_5.pth')
# Out:
# Epoch 1/100, Train Loss: 0.9337, Validation Loss: 0.8960
# Epoch 2/100, Train Loss: 0.9125, Validation Loss: 0.7764
# Epoch 3/100, Train Loss: 0.9043, Validation Loss: 0.7009
# Epoch 4/100, Train Loss: 0.8868, Validation Loss: 0.6338
# Epoch 5/100, Train Loss: 0.8566, Validation Loss: 0.5734
# Epoch 6/100, Train Loss: 0.8215, Validation Loss: 0.5212
# Epoch 7/100, Train Loss: 0.7810, Validation Loss: 0.4783
# Epoch 8/100, Train Loss: 0.7502, Validation Loss: 0.4467
# Epoch 9/100, Train Loss: 0.7266, Validation Loss: 0.4311
# Epoch 10/100, Train Loss: 0.6949, Validation Loss: 0.4185
# Epoch 11/100, Train Loss: 0.6702, Validation Loss: 0.4127
# Epoch 12/100, Train Loss: 0.6522, Validation Loss: 0.4106
# Epoch 13/100, Train Loss: 0.6307, Validation Loss: 0.4055
# Epoch 14/100, Train Loss: 0.6146, Validation Loss: 0.4050
# Epoch 15/100, Train Loss: 0.6057, Validation Loss: 0.4024
# Epoch 16/100, Train Loss: 0.5998, Validation Loss: 0.4018
# Epoch 17/100, Train Loss: 0.5973, Validation Loss: 0.4043
# Epoch 18/100, Train Loss: 0.5852, Validation Loss: 0.4007
# Epoch 19/100, Train Loss: 0.5777, Validation Loss: 0.4033
# Epoch 20/100, Train Loss: 0.5682, Validation Loss: 0.4040
# Epoch 21/100, Train Loss: 0.5743, Validation Loss: 0.4061
# Epoch 22/100, Train Loss: 0.5734, Validation Loss: 0.4085
# Epoch 23/100, Train Loss: 0.5625, Validation Loss: 0.4065
# Epoch 24/100, Train Loss: 0.5550, Validation Loss: 0.4107
# Epoch 25/100, Train Loss: 0.5566, Validation Loss: 0.4110
# Epoch 26/100, Train Loss: 0.5529, Validation Loss: 0.4146
# Epoch 27/100, Train Loss: 0.5533, Validation Loss: 0.4174
# Epoch 28/100, Train Loss: 0.5447, Validation Loss: 0.4182
# Epoch 29/100, Train Loss: 0.5455, Validation Loss: 0.4195
# Epoch 30/100, Train Loss: 0.5436, Validation Loss: 0.4237
# Epoch 31/100, Train Loss: 0.5405, Validation Loss: 0.4253
# Epoch 32/100, Train Loss: 0.5313, Validation Loss: 0.4249
# Epoch 33/100, Train Loss: 0.5251, Validation Loss: 0.4245
# Epoch 34/100, Train Loss: 0.5294, Validation Loss: 0.4208
# Epoch 35/100, Train Loss: 0.5200, Validation Loss: 0.4197
# Epoch 36/100, Train Loss: 0.5196, Validation Loss: 0.4264
# Epoch 37/100, Train Loss: 0.5112, Validation Loss: 0.4239
# Epoch 38/100, Train Loss: 0.5133, Validation Loss: 0.4287
# Epoch 39/100, Train Loss: 0.5128, Validation Loss: 0.4286
# Epoch 40/100, Train Loss: 0.5115, Validation Loss: 0.4278
# Epoch 41/100, Train Loss: 0.5143, Validation Loss: 0.4286
# Epoch 42/100, Train Loss: 0.5103, Validation Loss: 0.4278
# Epoch 43/100, Train Loss: 0.5099, Validation Loss: 0.4305
# Epoch 44/100, Train Loss: 0.5079, Validation Loss: 0.4327
# Epoch 45/100, Train Loss: 0.5122, Validation Loss: 0.4342
# Epoch 46/100, Train Loss: 0.5223, Validation Loss: 0.4386
# Epoch 47/100, Train Loss: 0.5075, Validation Loss: 0.4350
# Epoch 48/100, Train Loss: 0.5177, Validation Loss: 0.4350
# Epoch 49/100, Train Loss: 0.5123, Validation Loss: 0.4394
# Epoch 50/100, Train Loss: 0.5152, Validation Loss: 0.4397
# Epoch 51/100, Train Loss: 0.5066, Validation Loss: 0.4375
# Epoch 52/100, Train Loss: 0.5220, Validation Loss: 0.4409
# Epoch 53/100, Train Loss: 0.5297, Validation Loss: 0.4401
# Epoch 54/100, Train Loss: 0.5244, Validation Loss: 0.4413
# Epoch 55/100, Train Loss: 0.5203, Validation Loss: 0.4382
# Epoch 56/100, Train Loss: 0.5123, Validation Loss: 0.4369
# Epoch 57/100, Train Loss: 0.5111, Validation Loss: 0.4380
# Epoch 58/100, Train Loss: 0.5153, Validation Loss: 0.4416
# Epoch 59/100, Train Loss: 0.5100, Validation Loss: 0.4422
# Epoch 60/100, Train Loss: 0.5204, Validation Loss: 0.4460
# Epoch 61/100, Train Loss: 0.5126, Validation Loss: 0.4449
# Epoch 62/100, Train Loss: 0.4990, Validation Loss: 0.4434
# Epoch 63/100, Train Loss: 0.5105, Validation Loss: 0.4417
# Epoch 64/100, Train Loss: 0.5040, Validation Loss: 0.4383
# Epoch 65/100, Train Loss: 0.5004, Validation Loss: 0.4403
# Epoch 66/100, Train Loss: 0.4937, Validation Loss: 0.4394
# Epoch 67/100, Train Loss: 0.4995, Validation Loss: 0.4433
# Epoch 68/100, Train Loss: 0.4928, Validation Loss: 0.4453
# Epoch 69/100, Train Loss: 0.4909, Validation Loss: 0.4502
# Epoch 70/100, Train Loss: 0.4983, Validation Loss: 0.4504
# Epoch 71/100, Train Loss: 0.4952, Validation Loss: 0.4480
# Epoch 72/100, Train Loss: 0.4955, Validation Loss: 0.4507
# Epoch 73/100, Train Loss: 0.4943, Validation Loss: 0.4544
# Epoch 74/100, Train Loss: 0.4767, Validation Loss: 0.4526
# Epoch 75/100, Train Loss: 0.4857, Validation Loss: 0.4556
# Epoch 76/100, Train Loss: 0.4880, Validation Loss: 0.4558
# Epoch 77/100, Train Loss: 0.4901, Validation Loss: 0.4552
# Epoch 78/100, Train Loss: 0.4740, Validation Loss: 0.4535
# Epoch 79/100, Train Loss: 0.4851, Validation Loss: 0.4525
# Epoch 80/100, Train Loss: 0.4859, Validation Loss: 0.4562
# Epoch 81/100, Train Loss: 0.4846, Validation Loss: 0.4530
# Epoch 82/100, Train Loss: 0.4763, Validation Loss: 0.4526
# Epoch 83/100, Train Loss: 0.4854, Validation Loss: 0.4488
# Epoch 84/100, Train Loss: 0.4735, Validation Loss: 0.4528
# Epoch 85/100, Train Loss: 0.4656, Validation Loss: 0.4502
# Epoch 86/100, Train Loss: 0.4720, Validation Loss: 0.4521
# Epoch 87/100, Train Loss: 0.4722, Validation Loss: 0.4517
# Epoch 88/100, Train Loss: 0.4768, Validation Loss: 0.4522
# Epoch 89/100, Train Loss: 0.4798, Validation Loss: 0.4525
# Epoch 90/100, Train Loss: 0.4838, Validation Loss: 0.4548
# Epoch 91/100, Train Loss: 0.4672, Validation Loss: 0.4562
# Epoch 92/100, Train Loss: 0.4784, Validation Loss: 0.4583
# Epoch 93/100, Train Loss: 0.4727, Validation Loss: 0.4515
# Epoch 94/100, Train Loss: 0.4745, Validation Loss: 0.4532
# Epoch 95/100, Train Loss: 0.4750, Validation Loss: 0.4541
# Epoch 96/100, Train Loss: 0.4662, Validation Loss: 0.4573
# Epoch 97/100, Train Loss: 0.4647, Validation Loss: 0.4526
# Epoch 98/100, Train Loss: 0.4707, Validation Loss: 0.4568
# Epoch 99/100, Train Loss: 0.4683, Validation Loss: 0.4533
# Epoch 100/100, Train Loss: 0.4675, Validation Loss: 0.4467

# %% [markdown]
# ## Kiểm thử

# %% [markdown]
# ### Trên tập valid

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_PCA3_ANN_withAug_var0_5.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in valid_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9524188805537147
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        72
#            1       0.75      0.89      0.81        81
#            2       0.92      0.79      0.85       117
#
#     accuracy                           0.87       270
#    macro avg       0.88      0.89      0.88       270
# weighted avg       0.88      0.87      0.87       270

# %% [markdown]
# ### Trên tập test

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_PCA3_ANN_withAug_var0_5.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9506801956954787
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        73
#            1       0.71      0.91      0.80        82
#            2       0.91      0.78      0.84       118
#
#     accuracy                           0.86       273
#    macro avg       0.88      0.87      0.87       273
# weighted avg       0.88      0.86      0.86       273

# %% [markdown]
# # Với số thành phần component là 7

# %%
num_components_with_elbow_method = 7

# %%
from torch.utils.data import DataLoader, TensorDataset

# Apply PCA
n_components = num_components_with_elbow_method
pca = PCA(n_components=n_components)
pca.fit(X_train_flat)

# Transform the data
X_train_pca = pca.transform(X_train_flat)
X_valid_pca = pca.transform(X_valid_flat)
X_test_pca = pca.transform(X_test_flat)

# Convert to PyTorch tensors
X_train = torch.tensor(X_train_pca, dtype=torch.float32)
y_train = torch.tensor(train_df_aug['label'].values, dtype=torch.long)
X_valid = torch.tensor(X_valid_pca, dtype=torch.float32)
y_valid = torch.tensor(valid_df['label'].values, dtype=torch.long)
X_test = torch.tensor(X_test_pca, dtype=torch.float32)
y_test = torch.tensor(test_df['label'].values, dtype=torch.long)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)

# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=120, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=120, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=120, shuffle=False)
# Out:
# torch.Size([94575, 7]) torch.Size([94575])
# torch.Size([270, 7]) torch.Size([270])
# torch.Size([273, 7]) torch.Size([273])

# %% [markdown]
# ## Huấn luyện mô hình

# %%
import torch
from src.models.module2.ann import ANN

model = ANN(input_dim=num_components_with_elbow_method, output_dim=3, num_hidden=9, num_layers=3, dropout=0.5)
num_params = sum(p.numel() for p in model.parameters())
print(num_params)
# Out:
# 282

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# set seed
torch.manual_seed(97)

model.to('cuda')
criterion.to('cuda')

num_epochs = 100
best_valid_loss = float('inf')
for epoch in range(num_epochs):
    model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    # Đánh giá mô hình trên tập validation
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)

    valid_loss /= len(valid_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss:.4f}, Validation Loss: {valid_loss:.4f}")

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'best_model_PCA7_ANN_withAug_var0_5.pth')
# Out:
# Epoch 1/100, Train Loss: 0.7587, Validation Loss: 0.9166
# Epoch 2/100, Train Loss: 0.7863, Validation Loss: 0.6565
# Epoch 3/100, Train Loss: 0.8315, Validation Loss: 0.5166
# Epoch 4/100, Train Loss: 0.8447, Validation Loss: 0.4672
# Epoch 5/100, Train Loss: 0.8353, Validation Loss: 0.4255
# Epoch 6/100, Train Loss: 0.7982, Validation Loss: 0.3945
# Epoch 7/100, Train Loss: 0.7685, Validation Loss: 0.3775
# Epoch 8/100, Train Loss: 0.7438, Validation Loss: 0.3708
# Epoch 9/100, Train Loss: 0.7198, Validation Loss: 0.3742
# Epoch 10/100, Train Loss: 0.6793, Validation Loss: 0.3763
# Epoch 11/100, Train Loss: 0.6612, Validation Loss: 0.3837
# Epoch 12/100, Train Loss: 0.6368, Validation Loss: 0.3867
# Epoch 13/100, Train Loss: 0.6209, Validation Loss: 0.3910
# Epoch 14/100, Train Loss: 0.6078, Validation Loss: 0.3943
# Epoch 15/100, Train Loss: 0.5992, Validation Loss: 0.3985
# Epoch 16/100, Train Loss: 0.5855, Validation Loss: 0.4010
# Epoch 17/100, Train Loss: 0.5818, Validation Loss: 0.4057
# Epoch 18/100, Train Loss: 0.5618, Validation Loss: 0.4034
# Epoch 19/100, Train Loss: 0.5500, Validation Loss: 0.4040
# Epoch 20/100, Train Loss: 0.5609, Validation Loss: 0.4066
# Epoch 21/100, Train Loss: 0.5605, Validation Loss: 0.4087
# Epoch 22/100, Train Loss: 0.5593, Validation Loss: 0.4086
# Epoch 23/100, Train Loss: 0.5405, Validation Loss: 0.4061
# Epoch 24/100, Train Loss: 0.5377, Validation Loss: 0.4095
# Epoch 25/100, Train Loss: 0.5470, Validation Loss: 0.4134
# Epoch 26/100, Train Loss: 0.5450, Validation Loss: 0.4136
# Epoch 27/100, Train Loss: 0.5417, Validation Loss: 0.4138
# Epoch 28/100, Train Loss: 0.5288, Validation Loss: 0.4135
# Epoch 29/100, Train Loss: 0.5499, Validation Loss: 0.4176
# Epoch 30/100, Train Loss: 0.5381, Validation Loss: 0.4201
# Epoch 31/100, Train Loss: 0.5404, Validation Loss: 0.4215
# Epoch 32/100, Train Loss: 0.5293, Validation Loss: 0.4230
# Epoch 33/100, Train Loss: 0.5388, Validation Loss: 0.4261
# Epoch 34/100, Train Loss: 0.5454, Validation Loss: 0.4276
# Epoch 35/100, Train Loss: 0.5024, Validation Loss: 0.4234
# Epoch 36/100, Train Loss: 0.5199, Validation Loss: 0.4310
# Epoch 37/100, Train Loss: 0.5165, Validation Loss: 0.4315
# Epoch 38/100, Train Loss: 0.5157, Validation Loss: 0.4320
# Epoch 39/100, Train Loss: 0.5199, Validation Loss: 0.4347
# Epoch 40/100, Train Loss: 0.5147, Validation Loss: 0.4379
# Epoch 41/100, Train Loss: 0.5255, Validation Loss: 0.4424
# Epoch 42/100, Train Loss: 0.5134, Validation Loss: 0.4434
# Epoch 43/100, Train Loss: 0.4966, Validation Loss: 0.4448
# Epoch 44/100, Train Loss: 0.4823, Validation Loss: 0.4462
# Epoch 45/100, Train Loss: 0.5223, Validation Loss: 0.4516
# Epoch 46/100, Train Loss: 0.5050, Validation Loss: 0.4531
# Epoch 47/100, Train Loss: 0.5000, Validation Loss: 0.4545
# Epoch 48/100, Train Loss: 0.5094, Validation Loss: 0.4591
# Epoch 49/100, Train Loss: 0.4932, Validation Loss: 0.4604
# Epoch 50/100, Train Loss: 0.4782, Validation Loss: 0.4593
# Epoch 51/100, Train Loss: 0.4610, Validation Loss: 0.4592
# Epoch 52/100, Train Loss: 0.4999, Validation Loss: 0.4652
# Epoch 53/100, Train Loss: 0.5018, Validation Loss: 0.4655
# Epoch 54/100, Train Loss: 0.4820, Validation Loss: 0.4629
# Epoch 55/100, Train Loss: 0.5054, Validation Loss: 0.4724
# Epoch 56/100, Train Loss: 0.5043, Validation Loss: 0.4710
# Epoch 57/100, Train Loss: 0.4997, Validation Loss: 0.4744
# Epoch 58/100, Train Loss: 0.4990, Validation Loss: 0.4781
# Epoch 59/100, Train Loss: 0.4844, Validation Loss: 0.4772
# Epoch 60/100, Train Loss: 0.5054, Validation Loss: 0.4825
# Epoch 61/100, Train Loss: 0.4876, Validation Loss: 0.4807
# Epoch 62/100, Train Loss: 0.4843, Validation Loss: 0.4797
# Epoch 63/100, Train Loss: 0.5013, Validation Loss: 0.4833
# Epoch 64/100, Train Loss: 0.4859, Validation Loss: 0.4875
# Epoch 65/100, Train Loss: 0.5087, Validation Loss: 0.4918
# Epoch 66/100, Train Loss: 0.5068, Validation Loss: 0.4939
# Epoch 67/100, Train Loss: 0.4810, Validation Loss: 0.4946
# Epoch 68/100, Train Loss: 0.4938, Validation Loss: 0.5024
# Epoch 69/100, Train Loss: 0.4921, Validation Loss: 0.5081
# Epoch 70/100, Train Loss: 0.4917, Validation Loss: 0.5112
# Epoch 71/100, Train Loss: 0.4842, Validation Loss: 0.5083
# Epoch 72/100, Train Loss: 0.4848, Validation Loss: 0.5046
# Epoch 73/100, Train Loss: 0.4796, Validation Loss: 0.5085
# Epoch 74/100, Train Loss: 0.4644, Validation Loss: 0.5045
# Epoch 75/100, Train Loss: 0.4754, Validation Loss: 0.5096
# Epoch 76/100, Train Loss: 0.4705, Validation Loss: 0.5135
# Epoch 77/100, Train Loss: 0.4992, Validation Loss: 0.5197
# Epoch 78/100, Train Loss: 0.4798, Validation Loss: 0.5168
# Epoch 79/100, Train Loss: 0.4991, Validation Loss: 0.5288
# Epoch 80/100, Train Loss: 0.5117, Validation Loss: 0.5363
# Epoch 81/100, Train Loss: 0.4927, Validation Loss: 0.5280
# Epoch 82/100, Train Loss: 0.4645, Validation Loss: 0.5308
# Epoch 83/100, Train Loss: 0.4856, Validation Loss: 0.5306
# Epoch 84/100, Train Loss: 0.5007, Validation Loss: 0.5380
# Epoch 85/100, Train Loss: 0.4933, Validation Loss: 0.5328
# Epoch 86/100, Train Loss: 0.4907, Validation Loss: 0.5345
# Epoch 87/100, Train Loss: 0.4964, Validation Loss: 0.5395
# Epoch 88/100, Train Loss: 0.5157, Validation Loss: 0.5434
# Epoch 89/100, Train Loss: 0.5095, Validation Loss: 0.5427
# Epoch 90/100, Train Loss: 0.4921, Validation Loss: 0.5492
# Epoch 91/100, Train Loss: 0.4972, Validation Loss: 0.5491
# Epoch 92/100, Train Loss: 0.4914, Validation Loss: 0.5540
# Epoch 93/100, Train Loss: 0.5105, Validation Loss: 0.5594
# Epoch 94/100, Train Loss: 0.5211, Validation Loss: 0.5654
# Epoch 95/100, Train Loss: 0.5131, Validation Loss: 0.5695
# Epoch 96/100, Train Loss: 0.4914, Validation Loss: 0.5697
# Epoch 97/100, Train Loss: 0.4832, Validation Loss: 0.5660
# Epoch 98/100, Train Loss: 0.5098, Validation Loss: 0.5749
# Epoch 99/100, Train Loss: 0.4862, Validation Loss: 0.5684
# Epoch 100/100, Train Loss: 0.4993, Validation Loss: 0.5763

# %% [markdown]
# ## Kiểm thử

# %% [markdown]
# ### Trên tập valid

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_PCA7_ANN_withAug_var0_5.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in valid_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.948094336090584
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        72
#            1       0.75      0.79      0.77        81
#            2       0.87      0.82      0.85       117
#
#     accuracy                           0.86       270
#    macro avg       0.86      0.87      0.86       270
# weighted avg       0.86      0.86      0.86       270

# %% [markdown]
# ## Trên tập test

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_PCA7_ANN_withAug_var0_5.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9507780240387108
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        73
#            1       0.75      0.84      0.79        82
#            2       0.88      0.82      0.85       118
#
#     accuracy                           0.86       273
#    macro avg       0.87      0.87      0.87       273
# weighted avg       0.87      0.86      0.86       273
