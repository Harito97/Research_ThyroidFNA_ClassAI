# %% [markdown]
# # Setup môi trường

# %%
import os
print(os.getcwd())
os.chdir("../../..")
print(os.getcwd())
# Out:
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase2_280824/notebooks/train_module2/with_aug_data
# /home/haipn/Clone/Research_ThyroidFNA_ClassAI/phase2_280824

# %%
import torch
from src.models.module2.vit import H13_63_ViT

model = H13_63_ViT()
num_params = sum(p.numel() for p in model.parameters())
print(num_params)
# Out:
# 1173

# %% [markdown]
# # Setup data

# %%
import pandas as pd

# Đọc dữ liệu từ CSV
data_dir = './data/processed/'
# train_df = pd.read_csv(data_dir + 'train_features.csv').drop(columns=['image_path'])
valid_df = pd.read_csv(data_dir + 'valid_features.csv').drop(columns=['image_path'])
test_df = pd.read_csv(data_dir + 'test_features.csv').drop(columns=['image_path'])

data_dir = './data/augmented/'
train_df_aug = pd.read_csv(data_dir + 'train_augmented_features.csv')

# Xem cấu trúc của DataFrame
# print('Train DataFrame:')
# print(train_df.head(3))
print('Valid DataFrame:')
print(valid_df.head(3))
print('Test DataFrame:')
print(test_df.head(3))
print('Train Augmented DataFrame:')
print(train_df_aug.head(3))
# Out:
# Valid DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2 -4.308372 -0.436520  3.545043 -2.595636 -1.076509  3.019734
# 1      2 -2.273990 -2.976918  4.630661 -5.481691  1.987185  3.077199
# 2      2 -4.070328 -3.232069  6.819434 -3.002290 -1.391492  3.774137
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -3.748788 -0.974676  4.619431  ...  4.596820 -4.209521 -0.469024  4.025341
# 1 -4.994466  1.433963  2.813911  ...  3.553807 -3.890979 -0.693126  4.631985
# 2 -2.197132 -2.203136  3.730880  ...  2.323358 -3.455380 -3.436366  6.039357
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -3.474844 -1.487661  5.017033 -1.916778 -0.383969  2.663312
# 1 -2.152809 -0.549343  3.090957 -1.015712 -1.852066  2.541131
# 2 -3.923026 -2.357094  5.158929 -4.472951 -3.406128  6.673154
#
# [3 rows x 40 columns]
# Test DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2 -3.796856  0.253959  2.877217 -5.331173  3.020115  1.696861
# 1      2 -1.773854 -2.388358  4.133105 -4.472247  2.485264  1.485237
# 2      2 -2.350752  0.081050  1.976886 -3.827375  2.962807  0.343403
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -5.202694  1.392334  2.969771  ...  3.350157 -3.535631  0.163143  2.530488
# 1 -4.855537 -0.433563  4.551636  ...  4.002171 -4.629158 -0.437382  4.171252
# 2 -5.119369  0.324123  3.400166  ...  0.545714 -3.568954 -0.028026  2.769698
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -4.519028  1.381369  2.529239 -1.612869  0.088159  2.034805
# 1 -4.309902 -0.884549  4.688826 -6.092622  0.102198  4.461133
# 2 -3.385958 -0.573338  3.277399 -0.740373  0.527510  0.592563
#
# [3 rows x 40 columns]
# Train Augmented DataFrame:
#    label     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0      2  1.518592 -2.122206  1.063359  1.083591 -3.078244  1.832143
# 1      2 -3.997844 -2.013066  5.606269 -2.221863  0.908517  0.995050
# 2      2 -4.144322 -3.335181  7.014940 -2.851661 -1.254374  4.090703
#
#       dim_6     dim_7     dim_8  ...    dim_29    dim_30    dim_31    dim_32  \
# 0 -3.617894  1.835063  0.739837  ... -0.450482  0.230301  0.322319 -0.361697
# 1 -4.953275  1.075495  3.199515  ...  2.695855 -4.411282 -1.748895  5.605376
# 2 -3.888599 -2.345787  6.091836  ...  6.469357 -5.430499 -2.013651  6.954945
#
#      dim_33    dim_34    dim_35    dim_36    dim_37    dim_38
# 0 -1.096648  1.402599  0.442939 -3.928780  2.343227  1.505659
# 1 -6.375985 -0.828269  6.179725 -4.965612  0.590781  3.893331
# 2 -3.220028 -1.721707  5.068684 -4.063029 -1.196603  5.176606
#
# [3 rows x 40 columns]

# %%
import torch
# Tính toán số lượng mẫu của mỗi lớp
class_counts = train_df_aug['label'].value_counts()
total_samples = len(train_df_aug)
class_weights = {cls: total_samples / (len(class_counts) * count) for cls, count in class_counts.items()}

# In ra thông tin trọng số
print("Class Weights (inverse frequency):")
print(class_weights)

# Chuyển đổi trọng số nhãn thành tensor
class_weights_tensor = torch.tensor(sorted(list(class_weights.values()), reverse=True), dtype=torch.float)
print(class_weights_tensor)
# Out:
# Class Weights (inverse frequency):
# {2: 0.7693833943833944, 1: 1.111331569664903, 0: 1.2493184634448575}
# tensor([1.2493, 1.1113, 0.7694])

# %%
from torch.utils.data import DataLoader, TensorDataset

# Chia dữ liệu thành các tensor
X_train = torch.tensor(train_df_aug.iloc[:, 1:].values, dtype=torch.float32).reshape(-1, 13, 3)
y_train = torch.tensor(train_df_aug['label'].values, dtype=torch.long)
X_valid = torch.tensor(valid_df.iloc[:, 1:].values, dtype=torch.float32).reshape(-1, 13, 3)
y_valid = torch.tensor(valid_df['label'].values, dtype=torch.long)
X_test = torch.tensor(test_df.iloc[:, 1:].values, dtype=torch.float32).reshape(-1, 13, 3)
y_test = torch.tensor(test_df['label'].values, dtype=torch.long)
print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)

# Tạo DataLoader
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=120, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=120, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=120, shuffle=False)
# Out:
# torch.Size([25205, 13, 3]) torch.Size([25205])
# torch.Size([270, 13, 3]) torch.Size([270])
# torch.Size([273, 13, 3]) torch.Size([273])

# %%
print(X_train[0])
# Out:
# tensor([[ 1.5186, -2.1222,  1.0634],
#         [ 1.0836, -3.0782,  1.8321],
#         [-3.6179,  1.8351,  0.7398],
#         [-1.4320, -0.4256,  1.7170],
#         [-1.4654,  0.8263,  0.9260],
#         [-1.4349, -2.0238,  3.4379],
#         [-1.2509,  0.4347,  1.2152],
#         [-3.5098, -0.6455,  4.2728],
#         [-1.4196, -0.5647,  1.8460],
#         [-0.7928,  1.6443, -0.4505],
#         [ 0.2303,  0.3223, -0.3617],
#         [-1.0966,  1.4026,  0.4429],
#         [-3.9288,  2.3432,  1.5057]])

# %% [markdown]
# # Huấn luyện mô hình

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# set seed
torch.manual_seed(97)

model.to('cuda')
criterion.to('cuda')

num_epochs = 300
best_valid_loss = float('inf')
for epoch in range(num_epochs):
    model.train()
    for inputs, labels in train_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    # Đánh giá mô hình trên tập validation
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)

    valid_loss /= len(valid_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Validation Loss: {valid_loss:.4f}")

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'best_model_H13_63_ViT_withAug.pth')
# Out:
# Epoch 1/300, Validation Loss: 0.8954
# Epoch 2/300, Validation Loss: 0.7491
# Epoch 3/300, Validation Loss: 0.6704
# Epoch 4/300, Validation Loss: 0.6037
# Epoch 5/300, Validation Loss: 0.5276
# Epoch 6/300, Validation Loss: 0.4720
# Epoch 7/300, Validation Loss: 0.4346
# Epoch 8/300, Validation Loss: 0.4058
# Epoch 9/300, Validation Loss: 0.3847
# Epoch 10/300, Validation Loss: 0.3675
# Epoch 11/300, Validation Loss: 0.3516
# Epoch 12/300, Validation Loss: 0.3402
# Epoch 13/300, Validation Loss: 0.3314
# Epoch 14/300, Validation Loss: 0.3238
# Epoch 15/300, Validation Loss: 0.3150
# Epoch 16/300, Validation Loss: 0.3089
# Epoch 17/300, Validation Loss: 0.3027
# Epoch 18/300, Validation Loss: 0.2975
# Epoch 19/300, Validation Loss: 0.2907
# Epoch 20/300, Validation Loss: 0.2855
# Epoch 21/300, Validation Loss: 0.2785
# Epoch 22/300, Validation Loss: 0.2736
# Epoch 23/300, Validation Loss: 0.2680
# Epoch 24/300, Validation Loss: 0.2635
# Epoch 25/300, Validation Loss: 0.2595
# Epoch 26/300, Validation Loss: 0.2570
# Epoch 27/300, Validation Loss: 0.2538
# Epoch 28/300, Validation Loss: 0.2508
# Epoch 29/300, Validation Loss: 0.2489
# Epoch 30/300, Validation Loss: 0.2485
# Epoch 31/300, Validation Loss: 0.2435
# Epoch 32/300, Validation Loss: 0.2416
# Epoch 33/300, Validation Loss: 0.2398
# Epoch 34/300, Validation Loss: 0.2375
# Epoch 35/300, Validation Loss: 0.2357
# Epoch 36/300, Validation Loss: 0.2340
# Epoch 37/300, Validation Loss: 0.2337
# Epoch 38/300, Validation Loss: 0.2291
# Epoch 39/300, Validation Loss: 0.2266
# Epoch 40/300, Validation Loss: 0.2237
# Epoch 41/300, Validation Loss: 0.2229
# Epoch 42/300, Validation Loss: 0.2205
# Epoch 43/300, Validation Loss: 0.2176
# Epoch 44/300, Validation Loss: 0.2164
# Epoch 45/300, Validation Loss: 0.2125
# Epoch 46/300, Validation Loss: 0.2098
# Epoch 47/300, Validation Loss: 0.2081
# Epoch 48/300, Validation Loss: 0.2061
# Epoch 49/300, Validation Loss: 0.2048
# Epoch 50/300, Validation Loss: 0.2017
# Epoch 51/300, Validation Loss: 0.2004
# Epoch 52/300, Validation Loss: 0.1967
# Epoch 53/300, Validation Loss: 0.1959
# Epoch 54/300, Validation Loss: 0.1942
# Epoch 55/300, Validation Loss: 0.1918
# Epoch 56/300, Validation Loss: 0.1906
# Epoch 57/300, Validation Loss: 0.1898
# Epoch 58/300, Validation Loss: 0.1872
# Epoch 59/300, Validation Loss: 0.1857
# Epoch 60/300, Validation Loss: 0.1839
# Epoch 61/300, Validation Loss: 0.1836
# Epoch 62/300, Validation Loss: 0.1808
# Epoch 63/300, Validation Loss: 0.1828
# Epoch 64/300, Validation Loss: 0.1801
# Epoch 65/300, Validation Loss: 0.1837
# Epoch 66/300, Validation Loss: 0.1786
# Epoch 67/300, Validation Loss: 0.1790
# Epoch 68/300, Validation Loss: 0.1763
# Epoch 69/300, Validation Loss: 0.1756
# Epoch 70/300, Validation Loss: 0.1750
# Epoch 71/300, Validation Loss: 0.1726
# Epoch 72/300, Validation Loss: 0.1738
# Epoch 73/300, Validation Loss: 0.1743
# Epoch 74/300, Validation Loss: 0.1702
# Epoch 75/300, Validation Loss: 0.1713
# Epoch 76/300, Validation Loss: 0.1696
# Epoch 77/300, Validation Loss: 0.1685
# Epoch 78/300, Validation Loss: 0.1681
# Epoch 79/300, Validation Loss: 0.1692
# Epoch 80/300, Validation Loss: 0.1687
# Epoch 81/300, Validation Loss: 0.1679
# Epoch 82/300, Validation Loss: 0.1689
# Epoch 83/300, Validation Loss: 0.1660
# Epoch 84/300, Validation Loss: 0.1661
# Epoch 85/300, Validation Loss: 0.1642
# Epoch 86/300, Validation Loss: 0.1655
# Epoch 87/300, Validation Loss: 0.1646
# Epoch 88/300, Validation Loss: 0.1619
# Epoch 89/300, Validation Loss: 0.1618
# Epoch 90/300, Validation Loss: 0.1605
# Epoch 91/300, Validation Loss: 0.1594
# Epoch 92/300, Validation Loss: 0.1619
# Epoch 93/300, Validation Loss: 0.1606
# Epoch 94/300, Validation Loss: 0.1573
# Epoch 95/300, Validation Loss: 0.1586
# Epoch 96/300, Validation Loss: 0.1586
# Epoch 97/300, Validation Loss: 0.1585
# Epoch 98/300, Validation Loss: 0.1599
# Epoch 99/300, Validation Loss: 0.1538
# Epoch 100/300, Validation Loss: 0.1556
# Epoch 101/300, Validation Loss: 0.1537
# Epoch 102/300, Validation Loss: 0.1585
# Epoch 103/300, Validation Loss: 0.1542
# Epoch 104/300, Validation Loss: 0.1549
# Epoch 105/300, Validation Loss: 0.1535
# Epoch 106/300, Validation Loss: 0.1525
# Epoch 107/300, Validation Loss: 0.1525
# Epoch 108/300, Validation Loss: 0.1507
# Epoch 109/300, Validation Loss: 0.1522
# Epoch 110/300, Validation Loss: 0.1501
# Epoch 111/300, Validation Loss: 0.1484
# Epoch 112/300, Validation Loss: 0.1499
# Epoch 113/300, Validation Loss: 0.1465
# Epoch 114/300, Validation Loss: 0.1524
# Epoch 115/300, Validation Loss: 0.1458
# Epoch 116/300, Validation Loss: 0.1467
# Epoch 117/300, Validation Loss: 0.1476
# Epoch 118/300, Validation Loss: 0.1434
# Epoch 119/300, Validation Loss: 0.1449
# Epoch 120/300, Validation Loss: 0.1459
# Epoch 121/300, Validation Loss: 0.1459
# Epoch 122/300, Validation Loss: 0.1469
# Epoch 123/300, Validation Loss: 0.1437
# Epoch 124/300, Validation Loss: 0.1444
# Epoch 125/300, Validation Loss: 0.1424
# Epoch 126/300, Validation Loss: 0.1448
# Epoch 127/300, Validation Loss: 0.1414
# Epoch 128/300, Validation Loss: 0.1404
# Epoch 129/300, Validation Loss: 0.1421
# Epoch 130/300, Validation Loss: 0.1430
# Epoch 131/300, Validation Loss: 0.1433
# Epoch 132/300, Validation Loss: 0.1395
# Epoch 133/300, Validation Loss: 0.1384
# Epoch 134/300, Validation Loss: 0.1369
# Epoch 135/300, Validation Loss: 0.1397
# Epoch 136/300, Validation Loss: 0.1356
# Epoch 137/300, Validation Loss: 0.1372
# Epoch 138/300, Validation Loss: 0.1373
# Epoch 139/300, Validation Loss: 0.1343
# Epoch 140/300, Validation Loss: 0.1376
# Epoch 141/300, Validation Loss: 0.1355
# Epoch 142/300, Validation Loss: 0.1354
# Epoch 143/300, Validation Loss: 0.1350
# Epoch 144/300, Validation Loss: 0.1346
# Epoch 145/300, Validation Loss: 0.1347
# Epoch 146/300, Validation Loss: 0.1329
# Epoch 147/300, Validation Loss: 0.1347
# Epoch 148/300, Validation Loss: 0.1370
# Epoch 149/300, Validation Loss: 0.1308
# Epoch 150/300, Validation Loss: 0.1337
# Epoch 151/300, Validation Loss: 0.1318
# Epoch 152/300, Validation Loss: 0.1315
# Epoch 153/300, Validation Loss: 0.1303
# Epoch 154/300, Validation Loss: 0.1316
# Epoch 155/300, Validation Loss: 0.1327
# Epoch 156/300, Validation Loss: 0.1312
# Epoch 157/300, Validation Loss: 0.1329
# Epoch 158/300, Validation Loss: 0.1291
# Epoch 159/300, Validation Loss: 0.1271
# Epoch 160/300, Validation Loss: 0.1257
# Epoch 161/300, Validation Loss: 0.1282
# Epoch 162/300, Validation Loss: 0.1283
# Epoch 163/300, Validation Loss: 0.1265
# Epoch 164/300, Validation Loss: 0.1267
# Epoch 165/300, Validation Loss: 0.1282
# Epoch 166/300, Validation Loss: 0.1264
# Epoch 167/300, Validation Loss: 0.1239
# Epoch 168/300, Validation Loss: 0.1259
# Epoch 169/300, Validation Loss: 0.1265
# Epoch 170/300, Validation Loss: 0.1273
# Epoch 171/300, Validation Loss: 0.1262
# Epoch 172/300, Validation Loss: 0.1248
# Epoch 173/300, Validation Loss: 0.1278
# Epoch 174/300, Validation Loss: 0.1237
# Epoch 175/300, Validation Loss: 0.1221
# Epoch 176/300, Validation Loss: 0.1240
# Epoch 177/300, Validation Loss: 0.1212
# Epoch 178/300, Validation Loss: 0.1260
# Epoch 179/300, Validation Loss: 0.1234
# Epoch 180/300, Validation Loss: 0.1255
# Epoch 181/300, Validation Loss: 0.1227
# Epoch 182/300, Validation Loss: 0.1260
# Epoch 183/300, Validation Loss: 0.1201
# Epoch 184/300, Validation Loss: 0.1280
# Epoch 185/300, Validation Loss: 0.1230
# Epoch 186/300, Validation Loss: 0.1227
# Epoch 187/300, Validation Loss: 0.1200
# Epoch 188/300, Validation Loss: 0.1196
# Epoch 189/300, Validation Loss: 0.1202
# Epoch 190/300, Validation Loss: 0.1206
# Epoch 191/300, Validation Loss: 0.1178
# Epoch 192/300, Validation Loss: 0.1212
# Epoch 193/300, Validation Loss: 0.1236
# Epoch 194/300, Validation Loss: 0.1220
# Epoch 195/300, Validation Loss: 0.1207
# Epoch 196/300, Validation Loss: 0.1183
# Epoch 197/300, Validation Loss: 0.1208
# Epoch 198/300, Validation Loss: 0.1203
# Epoch 199/300, Validation Loss: 0.1170
# Epoch 200/300, Validation Loss: 0.1195
# Epoch 201/300, Validation Loss: 0.1183
# Epoch 202/300, Validation Loss: 0.1204
# Epoch 203/300, Validation Loss: 0.1173
# Epoch 204/300, Validation Loss: 0.1185
# Epoch 205/300, Validation Loss: 0.1211
# Epoch 206/300, Validation Loss: 0.1161
# Epoch 207/300, Validation Loss: 0.1187
# Epoch 208/300, Validation Loss: 0.1198
# Epoch 209/300, Validation Loss: 0.1209
# Epoch 210/300, Validation Loss: 0.1201
# Epoch 211/300, Validation Loss: 0.1156
# Epoch 212/300, Validation Loss: 0.1166
# Epoch 213/300, Validation Loss: 0.1146
# Epoch 214/300, Validation Loss: 0.1171
# Epoch 215/300, Validation Loss: 0.1178
# Epoch 216/300, Validation Loss: 0.1152
# Epoch 217/300, Validation Loss: 0.1162
# Epoch 218/300, Validation Loss: 0.1174
# Epoch 219/300, Validation Loss: 0.1158
# Epoch 220/300, Validation Loss: 0.1148
# Epoch 221/300, Validation Loss: 0.1147
# Epoch 222/300, Validation Loss: 0.1140
# Epoch 223/300, Validation Loss: 0.1162
# Epoch 224/300, Validation Loss: 0.1185
# Epoch 225/300, Validation Loss: 0.1135
# Epoch 226/300, Validation Loss: 0.1160
# Epoch 227/300, Validation Loss: 0.1140
# Epoch 228/300, Validation Loss: 0.1158
# Epoch 229/300, Validation Loss: 0.1119
# Epoch 230/300, Validation Loss: 0.1151
# Epoch 231/300, Validation Loss: 0.1129
# Epoch 232/300, Validation Loss: 0.1132
# Epoch 233/300, Validation Loss: 0.1165
# Epoch 234/300, Validation Loss: 0.1105
# Epoch 235/300, Validation Loss: 0.1114
# Epoch 236/300, Validation Loss: 0.1130
# Epoch 237/300, Validation Loss: 0.1142
# Epoch 238/300, Validation Loss: 0.1134
# Epoch 239/300, Validation Loss: 0.1137
# Epoch 240/300, Validation Loss: 0.1104
# Epoch 241/300, Validation Loss: 0.1134
# Epoch 242/300, Validation Loss: 0.1149
# Epoch 243/300, Validation Loss: 0.1110
# Epoch 244/300, Validation Loss: 0.1125
# Epoch 245/300, Validation Loss: 0.1096
# Epoch 246/300, Validation Loss: 0.1113
# Epoch 247/300, Validation Loss: 0.1132
# Epoch 248/300, Validation Loss: 0.1091
# Epoch 249/300, Validation Loss: 0.1077
# Epoch 250/300, Validation Loss: 0.1078
# Epoch 251/300, Validation Loss: 0.1095
# Epoch 252/300, Validation Loss: 0.1127
# Epoch 253/300, Validation Loss: 0.1094
# Epoch 254/300, Validation Loss: 0.1099
# Epoch 255/300, Validation Loss: 0.1089
# Epoch 256/300, Validation Loss: 0.1092
# Epoch 257/300, Validation Loss: 0.1072
# Epoch 258/300, Validation Loss: 0.1117
# Epoch 259/300, Validation Loss: 0.1086
# Epoch 260/300, Validation Loss: 0.1122
# Epoch 261/300, Validation Loss: 0.1103
# Epoch 262/300, Validation Loss: 0.1075
# Epoch 263/300, Validation Loss: 0.1098
# Epoch 264/300, Validation Loss: 0.1065
# Epoch 265/300, Validation Loss: 0.1079
# Epoch 266/300, Validation Loss: 0.1082
# Epoch 267/300, Validation Loss: 0.1073
# Epoch 268/300, Validation Loss: 0.1066
# Epoch 269/300, Validation Loss: 0.1053
# Epoch 270/300, Validation Loss: 0.1049
# Epoch 271/300, Validation Loss: 0.1069
# Epoch 272/300, Validation Loss: 0.1036
# Epoch 273/300, Validation Loss: 0.1063
# Epoch 274/300, Validation Loss: 0.1080
# Epoch 275/300, Validation Loss: 0.1056
# Epoch 276/300, Validation Loss: 0.1055
# Epoch 277/300, Validation Loss: 0.1059
# Epoch 278/300, Validation Loss: 0.1057
# Epoch 279/300, Validation Loss: 0.1071
# Epoch 280/300, Validation Loss: 0.1045
# Epoch 281/300, Validation Loss: 0.1057
# Epoch 282/300, Validation Loss: 0.1050
# Epoch 283/300, Validation Loss: 0.1076
# Epoch 284/300, Validation Loss: 0.1055
# Epoch 285/300, Validation Loss: 0.1054
# Epoch 286/300, Validation Loss: 0.1035
# Epoch 287/300, Validation Loss: 0.1039
# Epoch 288/300, Validation Loss: 0.1049
# Epoch 289/300, Validation Loss: 0.1066
# Epoch 290/300, Validation Loss: 0.1060
# Epoch 291/300, Validation Loss: 0.1055
# Epoch 292/300, Validation Loss: 0.1038
# Epoch 293/300, Validation Loss: 0.1046
# Epoch 294/300, Validation Loss: 0.1031
# Epoch 295/300, Validation Loss: 0.1057
# Epoch 296/300, Validation Loss: 0.1027
# Epoch 297/300, Validation Loss: 0.1025
# Epoch 298/300, Validation Loss: 0.1018
# Epoch 299/300, Validation Loss: 0.1053
# Epoch 300/300, Validation Loss: 0.1028

# %% [markdown]
# # Kiểm thử

# %% [markdown]
# ## Trên tập train

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_H13_63_ViT_withAug.pth', weights_only=True, map_location='cpu'))
model.to('cuda')
# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in train_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9934154216747575
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6725
#            1       0.89      0.95      0.92      7560
#            2       0.97      0.91      0.94     10920
#
#     accuracy                           0.95     25205
#    macro avg       0.95      0.96      0.95     25205
# weighted avg       0.95      0.95      0.95     25205

# %% [markdown]
# ## Trên tập valid

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_H13_63_ViT_withAug.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in valid_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9945388446961916
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       0.89      0.98      0.93        81
#            2       0.98      0.91      0.95       117
#
#     accuracy                           0.96       270
#    macro avg       0.96      0.96      0.96       270
# weighted avg       0.96      0.96      0.96       270

# %% [markdown]
# ## Trên tập test

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

# Load mô hình tốt nhất
model.load_state_dict(torch.load('best_model_H13_63_ViT_withAug.pth', weights_only=True, map_location='cpu'))

# Dự đoán trên tập validation
model.eval()
y_true = []
y_pred = []
y_pred_prob = []  # Lưu xác suất dự đoán cho AUC
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model(inputs)
        prob = F.softmax(outputs, dim=1)  # Chuyển đổi đầu ra thành xác suất
        _, predicted = torch.max(outputs, 1)
        
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())
        y_pred_prob.extend(prob.cpu().numpy())  # Lưu xác suất dự đoán

# Chuyển đổi danh sách thành mảng NumPy
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_prob = np.array(y_pred_prob)

# Tính toán confusion matrix và classification report
conf_matrix = confusion_matrix(y_true, y_pred)
class_report = classification_report(y_true, y_pred)

# Tính toán AUC cho từng lớp
try:
    auc_scores = roc_auc_score(y_true, y_pred_prob, multi_class='ovr')
    print("\nAUC Scores for each class:")
    print(auc_scores)
except ValueError as e:
    print(f"ValueError: {e}")

print("\nClassification Report:")
print(class_report)

# Vẽ confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# AUC Scores for each class:
# 0.9555051451327623
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        73
#            1       0.74      0.87      0.80        82
#            2       0.89      0.83      0.86       118
#
#     accuracy                           0.86       273
#    macro avg       0.88      0.87      0.87       273
# weighted avg       0.87      0.86      0.87       273
